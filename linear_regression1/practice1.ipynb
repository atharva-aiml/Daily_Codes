# %%
import pandas as pd

# %%
df = pd.read_csv("50_Startups.csv")
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
Y = df[["PROFIT"]]

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
X = df[["RND"]]
X.head()
# Out:
#          RND
# 0  165349.20
# 1  162597.70
# 2  153441.51
# 3  144372.41
# 4  142107.34

# %%
import seaborn as sb
sb.scatterplot(data = df, x= "RND", y="PROFIT")
# Out:
# <Axes: xlabel='RND', ylabel='PROFIT'>

# %%
sb.regplot(data = df, x = "RND", y = "PROFIT")
# Out:
# <Axes: xlabel='RND', ylabel='PROFIT'>

# %%
sb.pairplot(data= df)

# %%
sb.residplot(data = df, x="RND", y = "PROFIT")
# Out:
# <Axes: xlabel='RND', ylabel='PROFIT'>

# %%
import sklearn as sk

# %%
model = sk.linear_
l.LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
pred = model.predict(X)

# %%
pred[0:5]
# Out:
# array([[190289.29389289],
#        [187938.71118575],
#        [180116.65707807],
#        [172369.00320589],
#        [170433.97345032]])

# %%
# Out:
# d:\ml codes\.venv\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
